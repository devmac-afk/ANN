# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle
import numpy as np
import pandas as pd

# %% [markdown]
# LOAD THE ANN TRAINED MODEL, SCALER , PICKLE , ONE-HOT ENCODING

# %%
model = load_model('churn_model.h5')
scaler = pickle.load(open('scaler.pkl', 'rb'))
ohe_geo = pickle.load(open('encode_geo.pkl', 'rb'))  # Contains OneHotEncoder for Geography
label_encoder_gender = pickle.load(open('label_encoder_gender.pkl', 'rb'))  # Contains LabelEncoder for Gender
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
input_data = {
    'Gender': 'Female',
    'Age': 34,
    'Tenure': 5,
    'Balance': 60000,
    'NumOfProducts': 2,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000,
    'CreditScore': 650,
    'Geography': 'France'
}

# %%
input_data_df = pd.DataFrame([input_data])
input_data_df
# Out:
#    Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0  Female   34       5    60000              2          1               1
#
#    EstimatedSalary  CreditScore Geography
# 0            50000          650    France

# %%
# APPLY ENCODING TO CATEGORICAL FEATURES
# 1. Geography (using ohe_geo - OneHotEncoder)
geo_encoded = ohe_geo.transform(input_data_df[['Geography']])
geo_encoded_df = pd.DataFrame(geo_encoded, columns=ohe_geo.get_feature_names_out(['Geography']))

# 2. Gender (using label_encoder_gender - LabelEncoder)  
input_data_df['Gender'] = label_encoder_gender.transform(input_data_df[['Gender']]).flatten()

# Combine encoded features and drop original Geography
input_data_df = pd.concat([input_data_df.drop('Geography', axis=1), geo_encoded_df], axis=1)

# 3. Scale numerical features
numerical_cols = input_data_df.select_dtypes(include=[np.number]).columns
input_data_df[numerical_cols] = scaler.transform(input_data_df[numerical_cols])

input_data_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 3
#       1 # APPLY ENCODING TO CATEGORICAL FEATURES
#       2 # 1. Geography (using ohe_geo - OneHotEncoder)
# ----> 3 geo_encoded = ohe_geo.transform(input_data_df[['Geography']])
#       4 geo_encoded_df = pd.DataFrame(geo_encoded, columns=ohe_geo.get_feature_names_out(['Geography']))
#       6 # 2. Gender (using label_encoder_gender - LabelEncoder)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'transform'
